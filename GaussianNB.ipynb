# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

sml_lr = pd.read_csv('filtered_dataset.csv', encoding = "ISO-8859-1")
sml_lr = sml_lr.dropna()
print(list(sml_lr.columns))

sml_lr2 = pd.DataFrame(sml_lr,columns=['gk_diving', 'gk_positioning', 'gk_reflexes', 'gk_handling', 'gk_kicking', 'heading_accuracy', 'dribbling', 'positioning','GoalKeeper'])
print(sml_lr2.shape)
print(list(sml_lr2.columns))

sml_lr_test = pd.read_csv('LeicesterCity-Skill-updated.csv',encoding = "ISO-8859-1")
sml_lr_test = sml_lr_test.dropna()
print(list(sml_lr_test.columns))

sml_lr_test2 = pd.DataFrame(sml_lr_test,columns=['gk_diving', 'gk_positioning', 'gk_reflexes', 'gk_handling', 'gk_kicking', 'heading_accuracy', 'dribbling', 'positioning','goalkeeper'])
print(sml_lr_test2.shape)
print(list(sml_lr_test2.columns))

X_train = sml_lr2.iloc[:,0:7]
y_train = sml_lr2.iloc[:,8]
X_test = sml_lr_test2.iloc[:,0:7]
y_test = sml_lr_test2.iloc[:,8]

X_train = X_train.astype(int)
y_train = y_train.astype(int)
X_test = X_test.astype(int)
y_test = y_test.astype(int)

print(X_train.shape)
print(y_train.shape)

gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred)) 

print('Accuracy of GNB on test set: {:.2f}'.format(gnb.score(X_test, y_test)))

print()
probabilityValueForEachPlayers = gnb.predict_proba(X_test)[:,1]
for value in probabilityValueForEachPlayers:
    print(value)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (1,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['ID', 'name', 'work_rate_att', 'work_rate_def', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'GoalKeeper', 'Forward', 'Midfielder', 'Defender']
# (17994, 9)
# ['gk_diving', 'gk_positioning', 'gk_reflexes', 'gk_handling', 'gk_kicking', 'heading_accuracy', 'dribbling', 'positioning', 'GoalKeeper']
# ['API_ID', 'full_name', 'work_rate_att', 'work_rate_def', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'midfielder', 'defender', 'goalkeeper', 'forward', 'probDefender', 'probForward', 'probMidfielder', 'probGoalkeeper']
# (27, 9)
# ['gk_diving', 'gk_positioning', 'gk_reflexes', 'gk_handling', 'gk_kicking', 'heading_accuracy', 'dribbling', 'positioning', 'goalkeeper']
# (17994, 7)
# (17994,)
# [[24  0]
#  [ 0  3]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        24
#           1       1.00      1.00      1.00         3
#
# avg / total       1.00      1.00      1.00        27
#
# Accuracy of GNB on test set: 1.00
#
# 5.440343953196118e-102
# 5.4638151040103126e-123
# 1.0
# 6.048181306701281e-115
# 4.027026785855628e-124
# 3.333473382639854e-143
# 9.04780108801936e-122
# 6.8238662981011125e-124
# 1.6650351558944576e-111
# 4.818519143127058e-127
# 4.957406702038469e-117
# 1.863452016113314e-143
# 4.460428169434502e-133
# 2.2830741140919307e-126
# 5.426956386776474e-115
# 5.110546316914907e-100
# 5.138211764523899e-107
# 1.1528295226603636e-125
# 9.125338009536983e-127
# 7.54306763579364e-92
# 6.751218317106992e-145
# 1.0
# 1.0
# 3.340178932303636e-111
# 1.1005286488639765e-112
# 4.9455491768583145e-116
# 5.314156582325697e-123
